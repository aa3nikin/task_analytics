# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
new_data = pd.read_excel('Tab3_zpl_2024.xlsx', sheet_name='с 2017 г.', header=4)
old_data = pd.read_excel('Tab3_zpl_2024.xlsx', sheet_name='2000-2016 гг.', header=2)


new_data = new_data.set_axis(['Отрасль'] + [str(x) for x in range(2017, 2025)], axis='columns')
old_data = old_data.set_axis(['Отрасль'] + [str(x) for x in range(2000, 2017)], axis='columns')


new_data = new_data.dropna(how='any')
old_data = old_data.dropna(how='any')


new_data = pd.concat([
    new_data,
    pd.DataFrame([['Средняя'] + new_data.iloc[:, 1:].mean().tolist()], 
                 columns=new_data.columns)
], ignore_index=True)

old_data = pd.concat([
    old_data,
    pd.DataFrame([['Средняя'] + old_data.iloc[:, 1:].mean().tolist()], 
                 columns=old_data.columns)
], ignore_index=True)
# Out:
#                                               Отрасль           2017  \
# 0                         лесоводство и лесозаготовки   27616.600000
# 1                           рыболовство и рыбоводство   68032.000000
# 2                          добыча полезных ископаемых   74474.100000
# 3                                         добыча угля   53065.000000
# 4                      добыча нефти и природного газа  104078.300000
# 5                            добыча металлических руд   61121.900000
# 6                         обрабатывающие производства   38501.500000
# 7                      производство пищевых продуктов   29920.100000
# 8                               производство напитков   37933.700000
# 9                       производство табачных изделий   94767.900000
# 10                   производство текстильных изделий   22370.600000
# 11                                производство одежды   20298.500000
# 12                производство кожи и изделий из кожи   20193.000000
# 13      обработка древесины и производство изделий...   25656.500000
# 14             производство бумаги и бумажных изделий   39630.700000
# 15      деятельность полиграфическая и копирование...   30898.800000
# 16                производство кокса и нефтепродуктов   95956.700000
# 17      производство химических веществ и химическ...   45893.800000
# 18      производство лекарственных средств и матер...   54261.500000
# 19      производство резиновых и пластмассовых изд...   30621.800000
# 20      производство прочей неметаллической минера...   30904.000000
# 21                      производство металлургическое   49496.400000
# 22      производство готовых металлических изделий...   35969.900000
# 23      производство компьютеров, электронных и оп...   46928.400000
# 24           производство электрического оборудования   36285.900000
# 25      производство машин и оборудования, не вклю...   37471.800000
# 26      производство автотранспортных средств, при...   38133.400000
# 27      производство прочих транспортных средств и...   44884.400000
# 28                                производство мебели   22188.100000
# 29                производство прочих готовых изделий   27913.100000
# 30               ремонт и монтаж машин и оборудования   41879.800000
# 31  обеспечение электрической энергией, газом и па...   44631.700000
# 32  водоснабжение; водоотведение, организация сбор...   29097.200000
# 33                                      строительство   33677.900000
# 34  торговля оптовая и розничная; ремонт автотранс...   32092.500000
# 35                         транспортировка и хранение   43966.800000
# 36  деятельность гостиниц и предприятий общественн...   23970.500000
# 37          деятельность в области информации и связи   58811.200000
# 38                деятельность финансовая и страховая   84904.000000
# 39  деятельность по операциям с недвижимым имуществом   30208.100000
# 40  деятельность профессиональная,научная и технич...   57178.800000
# 41           из нее научные исследования и разработки   66177.900000
# 42  деятельность административная и сопутствующие ...   27621.500000
# 43  государственное управление и обеспечение военн...   43499.700000
# 44                                        образование   30257.600000
# 45  деятельность в области здравоохранения и социа...   31980.300000
# 46  деятельность в области культуры, спорта, орган...   38200.100000
# 47                                            Средняя   43906.893617
#
#              2018           2019           2020           2021           2022  \
# 0    32701.000000   35426.200000   37855.000000   42151.800000   48327.200000
# 1    75766.000000   88603.800000   94983.000000  101547.400000  121726.200000
# 2    83178.000000   89343.700000   95359.000000  103473.500000  118375.700000
# 3    59439.000000   63352.800000   62600.000000   73576.600000   90716.500000
# 4   127771.000000  135363.700000  142175.000000  149585.100000  165623.800000
# 5    70721.000000   78519.900000   88154.000000   96365.200000  108316.600000
# 6    40722.000000   43855.000000   46510.000000   52409.600000   60438.700000
# 7    32272.000000   35175.000000   37589.000000   42604.500000   48466.900000
# 8    40305.000000   43204.100000   45435.000000   49861.500000   57248.300000
# 9   100426.000000  104081.700000  112017.000000  108429.900000  126445.900000
# 10   25179.000000   26465.700000   30101.000000   33857.000000   38709.400000
# 11   19819.000000   21065.400000   20927.000000   24311.700000   27351.700000
# 12   23576.000000   25680.300000   26913.000000   31771.200000   36445.000000
# 13   26177.000000   29398.900000   30864.000000   36313.800000   40464.400000
# 14   42755.000000   47513.100000   52275.000000   57976.300000   66540.400000
# 15   33554.000000   34290.700000   35708.000000   43267.100000   52210.100000
# 16   87591.000000   81685.200000   82106.000000   87214.400000   97720.300000
# 17   49159.000000   54331.600000   57339.000000   63701.800000   75282.500000
# 18   57644.000000   61588.900000   71064.000000   79568.200000   87532.300000
# 19   33581.000000   35623.400000   39662.000000   44817.400000   51471.000000
# 20   34301.000000   37986.600000   40787.000000   46264.600000   54046.100000
# 21   49982.000000   53539.400000   56928.000000   63232.000000   74947.700000
# 22   38431.000000   41416.200000   44034.000000   48425.000000   56481.100000
# 23   51492.000000   53981.900000   56672.000000   64613.900000   74834.500000
# 24   40992.000000   43659.900000   45693.000000   51037.900000   59094.600000
# 25   40036.000000   44128.100000   47499.000000   53730.400000   63377.400000
# 26   42015.000000   45378.300000   46549.000000   53235.800000   58517.700000
# 27   48033.000000   51659.400000   53524.000000   59789.400000   68310.800000
# 28   24213.000000   26888.300000   27786.000000   32224.200000   36897.300000
# 29   33214.000000   35600.900000   39825.000000   45131.900000   49937.600000
# 30   46167.000000   49316.600000   51789.000000   60311.800000   68760.300000
# 31   47482.000000   50381.500000   53157.000000   57804.200000   65452.000000
# 32   31586.000000   34517.900000   36347.000000   40038.600000   46075.400000
# 33   38518.000000   42629.900000   44738.000000   51944.200000   60849.500000
# 34   35444.000000   40137.000000   41867.000000   50388.800000   57806.100000
# 35   47474.000000   51160.200000   52939.000000   58391.300000   66925.500000
# 36   26241.000000   28191.400000   27411.000000   33224.700000   37571.700000
# 37   66590.000000   75898.200000   85648.000000   97434.400000  121262.400000
# 38   91070.000000  103667.800000  112680.000000  130223.300000  146637.100000
# 39   33101.000000   36859.400000   37628.000000   43620.300000   48531.300000
# 40   66264.000000   75192.800000   80077.000000   87329.400000  100842.800000
# 41   75913.000000   82286.900000   84973.000000   93278.500000  108101.600000
# 42   31706.000000   34002.400000   37090.000000   39225.100000   45067.300000
# 43   47803.000000   50990.500000   54496.000000   58620.300000   63505.200000
# 44   34361.000000   37071.900000   39563.000000   43390.500000   48400.200000
# 45   40027.000000   43122.100000   49532.000000   50690.100000   55419.600000
# 46   44439.000000   46990.400000   48445.000000   53340.300000   57490.600000
# 47   48281.510638   52153.723404   55474.744681   61483.934043   70522.474468
#
#              2023           2024
# 0    53542.800000   62613.400000
# 1   143135.100000  151311.600000
# 2   131588.400000  155556.600000
# 3   106604.600000  121960.100000
# 4   180947.000000  218539.400000
# 5   121607.600000  145645.400000
# 6    71855.100000   87008.100000
# 7    56864.700000   69637.300000
# 8    67023.600000   79458.500000
# 9   142865.700000  161486.900000
# 10   46274.900000   54630.900000
# 11   34199.300000   40030.700000
# 12   44351.200000   51240.000000
# 13   45866.700000   56834.200000
# 14   74146.400000   87906.700000
# 15   56699.200000   67859.000000
# 16  109466.800000  128863.700000
# 17   87872.900000  104785.800000
# 18   99882.000000  115307.900000
# 19   61706.700000   72628.400000
# 20   63601.900000   77432.000000
# 21   85499.100000  105254.100000
# 22   70379.900000   86192.400000
# 23   91970.400000  112116.800000
# 24   74239.500000   88783.400000
# 25   75962.800000   90834.300000
# 26   71244.100000   89292.100000
# 27   83413.500000  101030.500000
# 28   43087.500000   52101.400000
# 29   59188.500000   70838.300000
# 30   78738.500000   94757.800000
# 31   74438.300000   86498.600000
# 32   52706.900000   62754.800000
# 33   71707.000000   84291.300000
# 34   66225.700000   75228.200000
# 35   76223.300000   89359.300000
# 36   44132.500000   51520.100000
# 37  136987.500000  163531.400000
# 38  170600.200000  206318.400000
# 39   55442.800000   62162.000000
# 40  108252.800000  125933.500000
# 41  120790.000000  138032.400000
# 42   50573.000000   60277.800000
# 43   73949.300000   84925.600000
# 44   54314.800000   62912.900000
# 45   61651.100000   71208.400000
# 46   65702.100000   77858.100000
# 47   81223.908511   95845.755319

# %%
col_name_mapping = {
    'Рыболовство, рыбоводство': 'Рыболовство и рыбоводство',
    'Производство кожи, изделий из кожи и производство обуви': 'Производство кожи и изделий из кожи',
    'Производство резиновых и пластмассовых изделий': 'Производство резиновых и пластмассовых изделий',
    'Торговля оптовая и розничная; ремонт автотранспортных средств и мотоциклов': 'Оптовая и розничная торговля; ремонт автотранспортных средств, мотоциклов, бытовых изделий и предметов личного пользования',
    'Деятельность финансовая и страховая': 'Финансовая деятельность',
    'Государственное управление и обеспечение военной безопасности; социальное обеспечение': 'Государственное управление и обеспечение военной безопасности; социальное страхование',
    'Деятельность в области здравоохранения и социальных услуг': 'Здравоохранение и предоставление социальных услуг',

}

def sanitaze_str(str):
    str = str.strip().capitalize()
    str = re.sub(r'\s{2,}', ' ', str)
    if str in col_name_mapping:
        str = col_name_mapping[str]
    return str

new_data['Отрасль'] = new_data['Отрасль'].apply(sanitaze_str)
old_data['Отрасль'] = old_data['Отрасль'].apply(sanitaze_str)
data = old_data.merge(new_data, on='Отрасль')

data
# Out:
#                                               Отрасль         2000  \
# 0                           Рыболовство и рыбоводство  2845.600000
# 1                          Добыча полезных ископаемых  5940.200000
# 2                         Обрабатывающие производства  2365.200000
# 3                 Производство кожи и изделий из кожи  1347.800000
# 4                 Производство кокса и нефтепродуктов  4916.300000
# 5      Производство резиновых и пластмассовых изделий  2140.400000
# 6                                       Строительство  2639.800000
# 7   Оптовая и розничная торговля; ремонт автотранс...  1584.500000
# 8                             Финансовая деятельность  5232.200000
# 9   Государственное управление и обеспечение военн...  2712.100000
# 10                                        Образование  1240.200000
# 11  Здравоохранение и предоставление социальных услуг  1333.300000
# 12                                            Средняя  2752.722581
#
#            2001          2002          2003          2004          2005  \
# 0   3839.300000   5031.300000   5444.500000   7084.900000  10233.500000
# 1   9099.200000  11080.900000  13912.400000  16841.700000  19726.900000
# 2   3446.600000   4439.100000   5603.400000   6848.900000   8420.900000
# 3   1986.100000   2621.100000   3230.000000   3774.700000   4695.300000
# 4   7012.400000   9625.300000  11879.000000  13729.300000  19397.100000
# 5   3032.200000   3957.100000   4950.700000   5956.800000   6879.200000
# 6   3859.300000   4806.900000   6176.700000   7304.700000   9042.800000
# 7   2294.900000   3068.900000   3974.200000   4906.200000   6552.100000
# 8   8885.200000  13245.900000  15561.200000  17383.800000  22463.500000
# 9   3754.900000   5200.400000   6913.800000   7898.600000  10958.500000
# 10  1833.000000   2927.300000   3386.600000   4203.400000   5429.700000
# 11  1959.900000   3141.300000   3662.600000   4612.000000   5905.600000
# 12  4025.035484   5286.809677   6597.919355   7961.383871   9979.132258
#
#             2006         2007          2008  ...          2015          2016  \
# 0   12310.800000  14797.00000  19498.900000  ...  46676.000000  54927.000000
# 1   23145.200000  28107.50000  33206.100000  ...  63695.000000  69936.000000
# 2   10198.500000  12878.70000  16049.900000  ...  31910.000000  34592.000000
# 3    5649.100000   7537.00000   9522.300000  ...  17796.000000  19847.000000
# 4   22319.600000  28565.00000  34912.500000  ...  81605.000000  88194.000000
# 5    8767.700000  11082.60000  13464.000000  ...  25006.000000  27565.000000
# 6   10869.200000  14333.40000  18574.000000  ...  29960.000000  32332.000000
# 7    8234.900000  11476.30000  14927.400000  ...  26947.000000  30030.000000
# 8   27885.500000  34879.80000  41871.800000  ...  70088.000000  80289.000000
# 9   13477.300000  16896.30000  21344.100000  ...  41916.000000  43611.000000
# 10   6983.300000   8778.30000  11316.800000  ...  26928.000000  28088.000000
# 11   8059.900000  10036.60000  13048.600000  ...  28179.000000  29742.000000
# 12  12072.412903  15160.63871  18818.193548  ...  36527.903226  39791.096774
#
#             2017          2018           2019           2020           2021  \
# 0   68032.000000  75766.000000   88603.800000   94983.000000  101547.400000
# 1   74474.100000  83178.000000   89343.700000   95359.000000  103473.500000
# 2   38501.500000  40722.000000   43855.000000   46510.000000   52409.600000
# 3   20193.000000  23576.000000   25680.300000   26913.000000   31771.200000
# 4   95956.700000  87591.000000   81685.200000   82106.000000   87214.400000
# 5   30621.800000  33581.000000   35623.400000   39662.000000   44817.400000
# 6   33677.900000  38518.000000   42629.900000   44738.000000   51944.200000
# 7   32092.500000  35444.000000   40137.000000   41867.000000   50388.800000
# 8   84904.000000  91070.000000  103667.800000  112680.000000  130223.300000
# 9   43499.700000  47803.000000   50990.500000   54496.000000   58620.300000
# 10  30257.600000  34361.000000   37071.900000   39563.000000   43390.500000
# 11  31980.300000  40027.000000   43122.100000   49532.000000   50690.100000
# 12  43906.893617  48281.510638   52153.723404   55474.744681   61483.934043
#
#              2022           2023           2024
# 0   121726.200000  143135.100000  151311.600000
# 1   118375.700000  131588.400000  155556.600000
# 2    60438.700000   71855.100000   87008.100000
# 3    36445.000000   44351.200000   51240.000000
# 4    97720.300000  109466.800000  128863.700000
# 5    51471.000000   61706.700000   72628.400000
# 6    60849.500000   71707.000000   84291.300000
# 7    57806.100000   66225.700000   75228.200000
# 8   146637.100000  170600.200000  206318.400000
# 9    63505.200000   73949.300000   84925.600000
# 10   48400.200000   54314.800000   62912.900000
# 11   55419.600000   61651.100000   71208.400000
# 12   70522.474468   81223.908511   95845.755319
#
# [13 rows x 26 columns]

# %%
selected_industries = ["Образование", "Рыболовство и рыбоводство", "Строительство", "Средняя"]
industry_data = data.loc[selected_industries]
plt.figure(figsize=(12, 7))
styles = {
    "Образование": {'color': 'blue', 'marker': 'o', 'linestyle': '-', 'linewidth': 2},
    "Рыболовство и рыбоводство": {'color': 'green', 'marker': 's', 'linestyle': '--', 'linewidth': 2},
    "Строительство": {'color': 'red', 'marker': '^', 'linestyle': '-.', 'linewidth': 2},
    "Средняя": {'color': 'yellow', 'marker': '^', 'linestyle': '-.', 'linewidth': 2}

}

for industry in selected_industries:
    plt.plot(
        industry_data.columns, 
        industry_data.loc[industry], 
        label=industry,
        **styles[industry]
    )

plt.title('Среднемесячная номинальная начисленная заработная плата', fontsize=16)
plt.xlabel('Годы', fontsize=12)
plt.ylabel('З/П, руб', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
for industry in selected_industries:
    for i, value in enumerate(industry_data.loc[industry]):
        plt.annotate(
            f'{value}', 
            (i, value),
            xytext=(0, 10),
            fontsize=9
        )

plt.tight_layout()
plt.show()

# %% [markdown]
# Можно заметить, что среднемесячная номинальная заработная плата с каждым годом растет, однако с 2015 года люди, занимающиеся рыболовством имеет зп больше средней, в то время как строители и профессионалы в сфере образования зарабатывают меньше! Теперь я знаю куда идти!

# %%
infl = pd.read_excel('inflation.xlsx', index_col='Год')
infl = infl['Всего']
infl.name = 'Инфляция'
infl = infl.iloc[1:]
infl = infl.sort_index()

# %%
def discount(year_from, year_to, sum):
    result = sum
    for x in range(year_from, year_to, -1):
        result /= 1.0 + infl.loc[x] / 100.0
    return result
data
# Out:
#                                                            2000         2001  \
# Отрасль
# Рыболовство и рыбоводство                           2845.600000  3839.300000
# Добыча полезных ископаемых                          5940.200000  9099.200000
# Обрабатывающие производства                         2365.200000  3446.600000
# Производство кожи и изделий из кожи                 1347.800000  1986.100000
# Производство кокса и нефтепродуктов                 4916.300000  7012.400000
# Производство резиновых и пластмассовых изделий      2140.400000  3032.200000
# Строительство                                       2639.800000  3859.300000
# Оптовая и розничная торговля; ремонт автотрансп...  1584.500000  2294.900000
# Финансовая деятельность                             5232.200000  8885.200000
# Государственное управление и обеспечение военно...  2712.100000  3754.900000
# Образование                                         1240.200000  1833.000000
# Здравоохранение и предоставление социальных услуг   1333.300000  1959.900000
# Средняя                                             2752.722581  4025.035484
#
#                                                             2002  \
# Отрасль
# Рыболовство и рыбоводство                            5031.300000
# Добыча полезных ископаемых                          11080.900000
# Обрабатывающие производства                          4439.100000
# Производство кожи и изделий из кожи                  2621.100000
# Производство кокса и нефтепродуктов                  9625.300000
# Производство резиновых и пластмассовых изделий       3957.100000
# Строительство                                        4806.900000
# Оптовая и розничная торговля; ремонт автотрансп...   3068.900000
# Финансовая деятельность                             13245.900000
# Государственное управление и обеспечение военно...   5200.400000
# Образование                                          2927.300000
# Здравоохранение и предоставление социальных услуг    3141.300000
# Средняя                                              5286.809677
#
#                                                             2003  \
# Отрасль
# Рыболовство и рыбоводство                            5444.500000
# Добыча полезных ископаемых                          13912.400000
# Обрабатывающие производства                          5603.400000
# Производство кожи и изделий из кожи                  3230.000000
# Производство кокса и нефтепродуктов                 11879.000000
# Производство резиновых и пластмассовых изделий       4950.700000
# Строительство                                        6176.700000
# Оптовая и розничная торговля; ремонт автотрансп...   3974.200000
# Финансовая деятельность                             15561.200000
# Государственное управление и обеспечение военно...   6913.800000
# Образование                                          3386.600000
# Здравоохранение и предоставление социальных услуг    3662.600000
# Средняя                                              6597.919355
#
#                                                             2004  \
# Отрасль
# Рыболовство и рыбоводство                            7084.900000
# Добыча полезных ископаемых                          16841.700000
# Обрабатывающие производства                          6848.900000
# Производство кожи и изделий из кожи                  3774.700000
# Производство кокса и нефтепродуктов                 13729.300000
# Производство резиновых и пластмассовых изделий       5956.800000
# Строительство                                        7304.700000
# Оптовая и розничная торговля; ремонт автотрансп...   4906.200000
# Финансовая деятельность                             17383.800000
# Государственное управление и обеспечение военно...   7898.600000
# Образование                                          4203.400000
# Здравоохранение и предоставление социальных услуг    4612.000000
# Средняя                                              7961.383871
#
#                                                             2005  \
# Отрасль
# Рыболовство и рыбоводство                           10233.500000
# Добыча полезных ископаемых                          19726.900000
# Обрабатывающие производства                          8420.900000
# Производство кожи и изделий из кожи                  4695.300000
# Производство кокса и нефтепродуктов                 19397.100000
# Производство резиновых и пластмассовых изделий       6879.200000
# Строительство                                        9042.800000
# Оптовая и розничная торговля; ремонт автотрансп...   6552.100000
# Финансовая деятельность                             22463.500000
# Государственное управление и обеспечение военно...  10958.500000
# Образование                                          5429.700000
# Здравоохранение и предоставление социальных услуг    5905.600000
# Средняя                                              9979.132258
#
#                                                             2006         2007  \
# Отрасль
# Рыболовство и рыбоводство                           12310.800000  14797.00000
# Добыча полезных ископаемых                          23145.200000  28107.50000
# Обрабатывающие производства                         10198.500000  12878.70000
# Производство кожи и изделий из кожи                  5649.100000   7537.00000
# Производство кокса и нефтепродуктов                 22319.600000  28565.00000
# Производство резиновых и пластмассовых изделий       8767.700000  11082.60000
# Строительство                                       10869.200000  14333.40000
# Оптовая и розничная торговля; ремонт автотрансп...   8234.900000  11476.30000
# Финансовая деятельность                             27885.500000  34879.80000
# Государственное управление и обеспечение военно...  13477.300000  16896.30000
# Образование                                          6983.300000   8778.30000
# Здравоохранение и предоставление социальных услуг    8059.900000  10036.60000
# Средняя                                             12072.412903  15160.63871
#
#                                                             2008     2009  \
# Отрасль
# Рыболовство и рыбоводство                           19498.900000  22913.5
# Добыча полезных ископаемых                          33206.100000  35363.4
# Обрабатывающие производства                         16049.900000  16583.1
# Производство кожи и изделий из кожи                  9522.300000  10073.2
# Производство кокса и нефтепродуктов                 34912.500000  37963.7
# Производство резиновых и пластмассовых изделий      13464.000000  13850.6
# Строительство                                       18574.000000  18122.2
# Оптовая и розничная торговля; ремонт автотрансп...  14927.400000  15958.6
# Финансовая деятельность                             41871.800000  42372.9
# Государственное управление и обеспечение военно...  21344.100000  23960.0
# Образование                                         11316.800000  13293.6
# Здравоохранение и предоставление социальных услуг   13048.600000  14819.5
# Средняя                                             18818.193548  19902.3
#
#                                                     ...          2015  \
# Отрасль                                             ...
# Рыболовство и рыбоводство                           ...  46676.000000
# Добыча полезных ископаемых                          ...  63695.000000
# Обрабатывающие производства                         ...  31910.000000
# Производство кожи и изделий из кожи                 ...  17796.000000
# Производство кокса и нефтепродуктов                 ...  81605.000000
# Производство резиновых и пластмассовых изделий      ...  25006.000000
# Строительство                                       ...  29960.000000
# Оптовая и розничная торговля; ремонт автотрансп...  ...  26947.000000
# Финансовая деятельность                             ...  70088.000000
# Государственное управление и обеспечение военно...  ...  41916.000000
# Образование                                         ...  26928.000000
# Здравоохранение и предоставление социальных услуг   ...  28179.000000
# Средняя                                             ...  36527.903226
#
#                                                             2016  \
# Отрасль
# Рыболовство и рыбоводство                           54927.000000
# Добыча полезных ископаемых                          69936.000000
# Обрабатывающие производства                         34592.000000
# Производство кожи и изделий из кожи                 19847.000000
# Производство кокса и нефтепродуктов                 88194.000000
# Производство резиновых и пластмассовых изделий      27565.000000
# Строительство                                       32332.000000
# Оптовая и розничная торговля; ремонт автотрансп...  30030.000000
# Финансовая деятельность                             80289.000000
# Государственное управление и обеспечение военно...  43611.000000
# Образование                                         28088.000000
# Здравоохранение и предоставление социальных услуг   29742.000000
# Средняя                                             39791.096774
#
#                                                             2017  \
# Отрасль
# Рыболовство и рыбоводство                           68032.000000
# Добыча полезных ископаемых                          74474.100000
# Обрабатывающие производства                         38501.500000
# Производство кожи и изделий из кожи                 20193.000000
# Производство кокса и нефтепродуктов                 95956.700000
# Производство резиновых и пластмассовых изделий      30621.800000
# Строительство                                       33677.900000
# Оптовая и розничная торговля; ремонт автотрансп...  32092.500000
# Финансовая деятельность                             84904.000000
# Государственное управление и обеспечение военно...  43499.700000
# Образование                                         30257.600000
# Здравоохранение и предоставление социальных услуг   31980.300000
# Средняя                                             43906.893617
#
#                                                             2018  \
# Отрасль
# Рыболовство и рыбоводство                           75766.000000
# Добыча полезных ископаемых                          83178.000000
# Обрабатывающие производства                         40722.000000
# Производство кожи и изделий из кожи                 23576.000000
# Производство кокса и нефтепродуктов                 87591.000000
# Производство резиновых и пластмассовых изделий      33581.000000
# Строительство                                       38518.000000
# Оптовая и розничная торговля; ремонт автотрансп...  35444.000000
# Финансовая деятельность                             91070.000000
# Государственное управление и обеспечение военно...  47803.000000
# Образование                                         34361.000000
# Здравоохранение и предоставление социальных услуг   40027.000000
# Средняя                                             48281.510638
#
#                                                              2019  \
# Отрасль
# Рыболовство и рыбоводство                            88603.800000
# Добыча полезных ископаемых                           89343.700000
# Обрабатывающие производства                          43855.000000
# Производство кожи и изделий из кожи                  25680.300000
# Производство кокса и нефтепродуктов                  81685.200000
# Производство резиновых и пластмассовых изделий       35623.400000
# Строительство                                        42629.900000
# Оптовая и розничная торговля; ремонт автотрансп...   40137.000000
# Финансовая деятельность                             103667.800000
# Государственное управление и обеспечение военно...   50990.500000
# Образование                                          37071.900000
# Здравоохранение и предоставление социальных услуг    43122.100000
# Средняя                                              52153.723404
#
#                                                              2020  \
# Отрасль
# Рыболовство и рыбоводство                            94983.000000
# Добыча полезных ископаемых                           95359.000000
# Обрабатывающие производства                          46510.000000
# Производство кожи и изделий из кожи                  26913.000000
# Производство кокса и нефтепродуктов                  82106.000000
# Производство резиновых и пластмассовых изделий       39662.000000
# Строительство                                        44738.000000
# Оптовая и розничная торговля; ремонт автотрансп...   41867.000000
# Финансовая деятельность                             112680.000000
# Государственное управление и обеспечение военно...   54496.000000
# Образование                                          39563.000000
# Здравоохранение и предоставление социальных услуг    49532.000000
# Средняя                                              55474.744681
#
#                                                              2021  \
# Отрасль
# Рыболовство и рыбоводство                           101547.400000
# Добыча полезных ископаемых                          103473.500000
# Обрабатывающие производства                          52409.600000
# Производство кожи и изделий из кожи                  31771.200000
# Производство кокса и нефтепродуктов                  87214.400000
# Производство резиновых и пластмассовых изделий       44817.400000
# Строительство                                        51944.200000
# Оптовая и розничная торговля; ремонт автотрансп...   50388.800000
# Финансовая деятельность                             130223.300000
# Государственное управление и обеспечение военно...   58620.300000
# Образование                                          43390.500000
# Здравоохранение и предоставление социальных услуг    50690.100000
# Средняя                                              61483.934043
#
#                                                              2022  \
# Отрасль
# Рыболовство и рыбоводство                           121726.200000
# Добыча полезных ископаемых                          118375.700000
# Обрабатывающие производства                          60438.700000
# Производство кожи и изделий из кожи                  36445.000000
# Производство кокса и нефтепродуктов                  97720.300000
# Производство резиновых и пластмассовых изделий       51471.000000
# Строительство                                        60849.500000
# Оптовая и розничная торговля; ремонт автотрансп...   57806.100000
# Финансовая деятельность                             146637.100000
# Государственное управление и обеспечение военно...   63505.200000
# Образование                                          48400.200000
# Здравоохранение и предоставление социальных услуг    55419.600000
# Средняя                                              70522.474468
#
#                                                              2023  \
# Отрасль
# Рыболовство и рыбоводство                           143135.100000
# Добыча полезных ископаемых                          131588.400000
# Обрабатывающие производства                          71855.100000
# Производство кожи и изделий из кожи                  44351.200000
# Производство кокса и нефтепродуктов                 109466.800000
# Производство резиновых и пластмассовых изделий       61706.700000
# Строительство                                        71707.000000
# Оптовая и розничная торговля; ремонт автотрансп...   66225.700000
# Финансовая деятельность                             170600.200000
# Государственное управление и обеспечение военно...   73949.300000
# Образование                                          54314.800000
# Здравоохранение и предоставление социальных услуг    61651.100000
# Средняя                                              81223.908511
#
#                                                              2024
# Отрасль
# Рыболовство и рыбоводство                           151311.600000
# Добыча полезных ископаемых                          155556.600000
# Обрабатывающие производства                          87008.100000
# Производство кожи и изделий из кожи                  51240.000000
# Производство кокса и нефтепродуктов                 128863.700000
# Производство резиновых и пластмассовых изделий       72628.400000
# Строительство                                        84291.300000
# Оптовая и розничная торговля; ремонт автотрансп...   75228.200000
# Финансовая деятельность                             206318.400000
# Государственное управление и обеспечение военно...   84925.600000
# Образование                                          62912.900000
# Здравоохранение и предоставление социальных услуг    71208.400000
# Средняя                                              95845.755319
#
# [13 rows x 25 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(12, 7))
colors = plt.cm.tab10.colors
color_idx = 0
lines = ["Образование", "Рыболовство и рыбоводство", "Строительство", "Средняя"]

for name in lines:
    dt = data.loc[name]         
    dt_real = data_2000.loc[name] 
    years = dt.index.astype(int)
    years_real = dt_real.index.astype(int)
    
    ax.plot(years_real, dt_real.values, 
            label=f'{name} с учетом инфл.', 
            color=colors[color_idx])
    
    ax.plot(years, dt.values, 
            label=name, 
            linestyle=':', 
            linewidth=2.5,
            color=colors[color_idx])
    
    color_idx = (color_idx + 1) % len(colors) 

ax.set_xlabel('Год', fontsize=12)
ax.set_ylabel('Зарплата, руб.', fontsize=12)
ax.set_yscale('log')  
ax.grid(True, which='both', linestyle='--', alpha=0.6)
ax.legend(fontsize=10, loc='best')
ax.set_title('Динамика зарплат по отраслям', fontsize=14)
ax.set_xticks(np.arange(2000, 2024, 3))
ax.tick_params(axis='both', which='major', labelsize=10)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

changes = pd.DataFrame(index=data_2000.index)
for year in range(2001, 2024):
    prev_year = year - 1
    if str(year) in data_2000.columns and str(prev_year) in data_2000.columns:
        changes[str(year)] = (data_2000[str(year)] / data_2000[str(prev_year)] - 1) * 100
    else:
        changes[str(year)] = np.nan  


fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 12), sharex=True)

colors = plt.cm.tab10.colors
years = np.arange(2000, 2024)
color_idx = 0

for name in lines:
    real_salaries = data_2000.loc[name, [str(y) for y in years]].values.astype(float)
    if len(years) != len(real_salaries):
        real_salaries = real_salaries[:len(years)] if len(real_salaries) > len(years) else real_salaries
    
    ax1.plot(years, real_salaries, 
             label=name, 
             color=colors[color_idx],
             marker='o',
             linewidth=2)
    
    color_idx = (color_idx + 1) % len(colors)

ax1.set_title('Реальные зарплаты с учетом инфляции (в рублях 2000 года)', fontsize=14)
ax1.set_ylabel('Зарплата, руб.', fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.7)
ax1.legend(fontsize=10, loc='upper left', bbox_to_anchor=(1, 1))
ax1.set_yscale('log')
ax1.tick_params(axis='y', labelsize=10)


color_idx = 0
years_changes = np.arange(2001, 2024)

for name in lines:
    # Извлекаем данные изменений
    if name in changes.index:
        y_values = changes.loc[name, [str(y) for y in years_changes]].values.astype(float)
        

        if len(y_values) != len(years_changes):
            print(f"Ошибка размера изменений для {name}: годы {len(years_changes)} vs данные {len(y_values)}")
            y_values = y_values[:len(years_changes)] if len(y_values) > len(years_changes) else y_values
        

        colors_bars = ['#2ca02c' if v >= 0 else '#d62728' for v in y_values]
        

        pos_offset = 0.15 * (color_idx - len(lines)/2) / len(lines)
        positions = years_changes + pos_offset
        
        bars = ax2.bar(
            positions, 
            y_values, 
            width=0.15, 
            color=colors_bars,
            label=name
        )
        

    
    color_idx = (color_idx + 1) % len(colors)

ax2.set_title('Годовое изменение реальных зарплат (%)', fontsize=14)
ax2.set_xlabel('Год', fontsize=12)
ax2.set_ylabel('Изменение, %', fontsize=12)
ax2.axhline(y=0, color='black', linewidth=0.8)
ax2.grid(True, axis='y', linestyle='--', alpha=0.7)
ax2.set_xticks(np.arange(2001, 2024, 2))
ax2.tick_params(axis='x', rotation=45, labelsize=10)
ax2.tick_params(axis='y', labelsize=10)

plt.tight_layout()
plt.subplots_adjust(hspace=0.1)
plt.savefig("диаграма.pdf")

# %% [markdown]
# Выводы по первому графику:
# Общий тренд: Все отрасли демонстрируют рост реальных зарплат за период 2000-2023 гг.
#
# Неравномерность роста-С
#
# Строительство и рыболовство показывают наиболее быстрый р-ст
#
# Образование отстает от других отсйдером
#
# Кризисные периоды: Видны точки замедления роста/падения (2009, 2014-2015 гг.)

# %% [markdown]
# Выводы по втрому графику:
# Волатильность отраслей:
# -
# Рыболовство/рыбоводство: самые резкие колебания (пики до +25%, падения до -15%-
#
# Строительство: высокая чувствительность к кризисам (глубокие падения в 2009, 20-5)
#
# Образование: относительно стабильная динамика изменений
#
# Кризисны годы:
#
# 2009: сильное падение во всех отраслях (максимум в строительстве  до -15%)
#
# 2015: повторное падение, но меее глубокое
#
# 2020: несмотря на пандемию, роста падения
# е наблюдается
#
# Периодывосстановления:
#
# 2010-2011: компенсационный рост осле кризиса 2009
#
# 2016-2018: устойчивый рост после кризиса 2015
